# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import sys, os
sys.path.append("..")
sys.path.append(os.path.join("../src/", "Solvers"))
sys.path.append(os.path.join("../src/", "Expert"))
from RwSolver import *
from Experiment import *
from Analyzer import *

# %%
df = Analyzer("medium_grid").df
df.columns
# Out:
# Index(['_id', 'actions', 'dataset_id', 'dataset_path', 'dataset_type', 'days',
#        'dummy_data_param', 'gamma', 'mean_order_response_rates', 'min_income',
#        'mode', 'n', 'number_of_cars', 'number_of_orders', 'order_distr',
#        'order_response_rates', 'orders_density', 'rewards', 'solver', 'tag',
#        'test_time', 'time_periods', 'time_periods_per_hour',
#        'train_test_split', 'train_time', 'trained_model_id', 'wc'],
#       dtype='object')

# %%
for i in df.index:
    plt.plot(df.loc[i]['rewards'],label=df.loc[i]['solver'])
plt.legend()
plt.xlabel("Testing Iteration")
plt.ylabel("Total Revenue per iteration")
# Out:
# Text(0, 0.5, 'Total Revenue per iteration')

# %%
for i in df.index:
    plt.plot(df.loc[i]['min_income'],label=df.loc[i]['solver'])
plt.legend()
plt.xlabel("Testing Iteration")
plt.ylabel("Total Revenue per iteration")
# Out:
# Text(0, 0.5, 'Total Revenue per iteration')
